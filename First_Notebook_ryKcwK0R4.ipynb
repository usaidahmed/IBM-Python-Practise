# %% [markdown]
# My Title

# %%
1 + 1
# Out:
# 2

# %%
x = "Hello World"
print (x)
# Out:
# Hello World

# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
#
# 1 .numbering
# 2 .numbering
# 3 .numbering
#
# **bold**
# _italics_
